# %%
import sys, site, pathlib

# %%
print(sys.executable)
# Out:
# /home/oem/miniconda3/envs/theAIE/bin/python

# %%
print(sys.prefix)
# Out:
# /home/oem/miniconda3/envs/theAIE

# %%
print(site.getsitepackages())
# Out:
# ['/home/oem/miniconda3/envs/theAIE/lib/python3.11/site-packages']
